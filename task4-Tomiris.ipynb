# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import scipy
from scipy import ndimage as ndi
from skimage import feature


original_img = cv2.imread('Tomi.jpg',0) 

canny_ed = cv2.Canny(original_img, 1, 2) 

sobel_ed = ndimage.sobel(original_img, mode = 'reflect', cval = 0.9)

fig = plt.figure(figsize=(15,10))
plt.subplot(221)
plt.imshow(original_image, cmap='gray')
plt.subplot(222)
plt.imshow(canny_edges, cmap='gray')
plt.subplot(223)
plt.imshow((sobel_edges), cmap='gray')
plt.subplot(224)
plt.imshow(original_image+120, cmap='gray') #just noise
plt.show()
